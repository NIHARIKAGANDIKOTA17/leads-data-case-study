# %% [markdown]
# # Lead Scoring Case Study

# %% [markdown]
# Problem Statement :
#     An education company named X Education sells online courses to industry professionals. On any given day, many professionals who are interested in the courses land on their website and browse for courses. The company markets its courses on several websites and search engines like Google. Once these people land on the website, they might browse the courses or fill up a form for the course or watch some videos. When these people fill up a form providing their email address or phone number, they are classified to be a lead. Moreover, the company also gets leads through past referrals. Once these leads are acquired, employees from the sales team start making calls, writing emails, etc. Through this process, some of the leads get converted while most do not. The typical lead conversion rate at X education is around 30%. There are a lot of leads generated in the initial stage (top) but only a few of them come out as paying customers from the bottom. In the middle stage, you need to nurture the potential leads well (i.e. educating the leads about the product, constantly communicating etc. ) in order to get a higher lead conversion. X Education has appointed you to help them select the most promising leads, i.e. the leads that are most likely to convert into paying customers. The company requires you to build a model wherein you need to assign a lead score to each of the leads such that the customers with higher lead score have a higher conversion chance and the customers with lower lead score have a lower conversion chance. The CEO, in particular, has given a ballpark of the target lead conversion rate to be around 80%.

# %% [markdown]
# The steps are broadly:
#
# 1. Read and understand the data
# 2. Data Cleaning and preparation
# 3. Prepare the data for Model Building
# 4. Exploratory data analysis
# 5. Splitting the data
# 6. Model buliding Using RFE
# 7. Model Evaluation
# 8. Making Predictions on the Test Set

# %%
# Importing libraries

# %%
import pandas as pd,numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step1: Read and Understanding the data

# %%
leads=pd.read_csv("Leads.csv")

# %%
# Looking first five entries
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# Inspect the shape of the dataset
leads.shape
# Out:
# (9240, 37)

# %% [markdown]
# #### leads datafram have 9240 rows and 37 columns

# %%
# Inspect the columns of the dataset
leads.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
leads.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
# Check the info to see the types of the feature variables and the null values present

leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %% [markdown]
# ## Step2 : Data cleaning and preparation

# %%
# Check the number of missing values in each column
mv=leads.isnull().sum().reset_index()
mv
# Out:
#                                             index     0
# 0                                     Prospect ID     0
# 1                                     Lead Number     0
# 2                                     Lead Origin     0
# 3                                     Lead Source    36
# 4                                    Do Not Email     0
# 5                                     Do Not Call     0
# 6                                       Converted     0
# 7                                     TotalVisits   137
# 8                     Total Time Spent on Website     0
# 9                            Page Views Per Visit   137
# 10                                  Last Activity   103
# 11                                        Country  2461
# 12                                 Specialization  1438
# 13             How did you hear about X Education  2207
# 14                What is your current occupation  2690
# 15  What matters most to you in choosing a course  2709
# ...

# %%
# Dropping the columns having null values sum is greater than 3000
drop_cols=list(mv[mv[0]>3000]["index"])
print(drop_cols)
# Out:
# ['Tags', 'Lead Quality', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index', 'Asymmetrique Activity Score', 'Asymmetrique Profile Score']

# %% [markdown]
# These are the columns going to drop

# %%
leads=leads.drop(drop_cols,axis=1)

# %% [markdown]
# #### Again Checking the missing values

# %%
mv=leads.isnull().sum().reset_index()
mv
# Out:
#                                             index     0
# 0                                     Prospect ID     0
# 1                                     Lead Number     0
# 2                                     Lead Origin     0
# 3                                     Lead Source    36
# 4                                    Do Not Email     0
# 5                                     Do Not Call     0
# 6                                       Converted     0
# 7                                     TotalVisits   137
# 8                     Total Time Spent on Website     0
# 9                            Page Views Per Visit   137
# 10                                  Last Activity   103
# 11                                        Country  2461
# 12                                 Specialization  1438
# 13             How did you hear about X Education  2207
# 14                What is your current occupation  2690
# 15  What matters most to you in choosing a course  2709
# ...

# %% [markdown]
#  As you might be able to interpret, the variable `City` and 'Country' won't be of any use in our analysis. So it's best that we drop it.

# %% [markdown]
#  Dropping 'city' and 'Country' columns

# %%
leads=leads.drop('City',axis=1)

# %%
leads=leads.drop('Country',axis=1)

# %%
# Get the value counts of all the columns
for c in leads.columns:
    print(leads[c].astype('category').value_counts())
# Out:
# 000104b9-23e4-4ddc-8caa-8629fe8ad7f4    1
# a7a319ea-b6ae-4c6b-afc5-183b933d10b5    1
# aa27a0af-eeab-4007-a770-fa8a93fa53c8    1
# aa30ebb2-8476-41ce-9258-37cc025110d3    1
# aa405742-17ac-4c65-b19e-ab91c241cc53    1
#                                        ..
# 539eb309-df36-4a89-ac58-6d3651393910    1
# 539ffa32-1be7-4fe1-b04c-faf1bab763cf    1
# 53aabd84-5dcc-4299-bbe3-62f3764b07b1    1
# 53ac14bd-2bb2-4315-a21c-94562d1b6b2d    1
# fffb0e5e-9f92-4017-9f42-781a69da4154    1
# Name: Prospect ID, Length: 9240, dtype: int64
# 579533    1
# 629593    1
# 630390    1
# 630403    1
# 630405    1
#          ..
# 602534    1
# 602540    1
# 602557    1
# 602561    1
# 660737    1
# Name: Lead Number, Length: 9240, dtype: int64
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# Quick Add Form                1
# Name: Lead Origin, dtype: int64
# Google               2868
# Direct Traffic       2543
# ...

# %% [markdown]
#  The following three columns now have the level 'Select'. Let's check them once again.

# %%
leads['Lead Profile'].value_counts()
# Out:
# Select                         4146
# Potential Lead                 1613
# Other Leads                     487
# Student of SomeSchool           241
# Lateral Student                  24
# Dual Specialization Student      20
# Name: Lead Profile, dtype: int64

# %%
leads['Specialization'].value_counts()
# Out:
# Select                               1942
# Finance Management                    976
# Human Resource Management             848
# Marketing Management                  838
# Operations Management                 503
# Business Administration               403
# IT Projects Management                366
# Supply Chain Management               349
# Banking, Investment And Insurance     338
# Travel and Tourism                    203
# Media and Advertising                 203
# International Business                178
# Healthcare Management                 159
# Hospitality Management                114
# E-COMMERCE                            112
# Retail Management                     100
# Rural and Agribusiness                 73
# E-Business                             57
# Services Excellence                    40
# Name: Specialization, dtype: int64

# %%
leads['How did you hear about X Education'].value_counts()
# Out:
# Select                   5043
# Online Search             808
# Word Of Mouth             348
# Student of SomeSchool     310
# Other                     186
# Multiple Sources          152
# Advertisements             70
# Social Media               67
# Email                      26
# SMS                        23
# Name: How did you hear about X Education, dtype: int64

# %% [markdown]
#  We can observe that the columms 'Lead Profile' and 'How did you hear about X Education' which are having more number 'select' values

# %%
# Dropping 'Lead Profile' and 'How did you hear about X Education' columns
leads=leads.drop('Lead Profile',axis=1)
leads=leads.drop('How did you hear about X Education',axis=1)

# %% [markdown]
# We can also observe that columns having high number of 'no' values in the columns 'Do Not Call', 'Search, Magazine',
# 'Newspaper Article', 'X Education Forums', 'Newspaper', 'Digital Advertisement', 'Through Recommendations',
# 'Receive More Updates About Our Courses', 'Update me on Supply Chain Content', 'Get updates on DM Content',
# 'I agree to pay the amount through cheque'.

# %%
# So, we can drop these columns
Dropping_col=['Do Not Call', 'Search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper', 'Digital Advertisement', 'Through Recommendations', 'Receive More Updates About Our Courses', 'Update me on Supply Chain Content', 'Get updates on DM Content', 'I agree to pay the amount through cheque']
leads=leads.drop(Dropping_col,axis=1)

# %%
# column 'What matters most to you in choosing a course ' 
leads['What matters most to you in choosing a course'].value_counts()
# Out:
# Better Career Prospects      6528
# Flexibility & Convenience       2
# Other                           1
# Name: What matters most to you in choosing a course, dtype: int64

# %%
# We can drop this column too because it has high values on Better Career Prospects and other two wing have very less values having 2 and 1.
leads=leads.drop('What matters most to you in choosing a course',axis=1)

# %%
# Checking the null values

leads.isnull().sum().sort_values(ascending=False)
# Out:
# What is your current occupation           2690
# Specialization                            1438
# TotalVisits                                137
# Page Views Per Visit                       137
# Last Activity                              103
# Lead Source                                 36
# Prospect ID                                  0
# Lead Number                                  0
# Lead Origin                                  0
# Do Not Email                                 0
# Converted                                    0
# Total Time Spent on Website                  0
# A free copy of Mastering The Interview       0
# Last Notable Activity                        0
# dtype: int64

# %%
# The column 'What is your current occupation' have high number of null values we can drop null values rows for this column
leads=leads[~pd.isnull(leads['What is your current occupation'])]

# %%
# Checking missing values
mv=leads.isnull().sum().reset_index()
mv
# Out:
#                                      index    0
# 0                              Prospect ID    0
# 1                              Lead Number    0
# 2                              Lead Origin    0
# 3                              Lead Source   36
# 4                             Do Not Email    0
# 5                                Converted    0
# 6                              TotalVisits  130
# 7              Total Time Spent on Website    0
# 8                     Page Views Per Visit  130
# 9                            Last Activity  103
# 10                          Specialization   18
# 11         What is your current occupation    0
# 12  A free copy of Mastering The Interview    0
# 13                   Last Notable Activity    0

# %%
# Dropping null values rows in the column 'TotalVisits'
leads=leads[~pd.isnull(leads['TotalVisits'])]

# %%
# Checking missing values
mv=leads.isnull().sum().reset_index()
mv
# Out:
#                                      index   0
# 0                              Prospect ID   0
# 1                              Lead Number   0
# 2                              Lead Origin   0
# 3                              Lead Source  29
# 4                             Do Not Email   0
# 5                                Converted   0
# 6                              TotalVisits   0
# 7              Total Time Spent on Website   0
# 8                     Page Views Per Visit   0
# 9                            Last Activity   0
# 10                          Specialization  18
# 11         What is your current occupation   0
# 12  A free copy of Mastering The Interview   0
# 13                   Last Notable Activity   0

# %%
# Droping the null values rows on the column 'Lead Source'
leads=leads[~pd.isnull(leads['Lead Source'])]

# %%
# Check the number of null values again

leads.isnull().sum().sort_values(ascending=False)
# Out:
# Specialization                            18
# Prospect ID                                0
# Lead Number                                0
# Lead Origin                                0
# Lead Source                                0
# Do Not Email                               0
# Converted                                  0
# TotalVisits                                0
# Total Time Spent on Website                0
# Page Views Per Visit                       0
# Last Activity                              0
# What is your current occupation            0
# A free copy of Mastering The Interview     0
# Last Notable Activity                      0
# dtype: int64

# %%
# Droping the null values rows on the column 'Lead Source'
leads=leads[~pd.isnull(leads['Specialization'])]

# %%
# Check the number of null values again

leads.isnull().sum().sort_values(ascending=False)
# Out:
# Prospect ID                               0
# Lead Number                               0
# Lead Origin                               0
# Lead Source                               0
# Do Not Email                              0
# Converted                                 0
# TotalVisits                               0
# Total Time Spent on Website               0
# Page Views Per Visit                      0
# Last Activity                             0
# Specialization                            0
# What is your current occupation           0
# A free copy of Mastering The Interview    0
# Last Notable Activity                     0
# dtype: int64

# %% [raw]
# Now your data doesn't have any null values. Let's now check the percentage of rows that we have retained.

# %%
print(len(leads.index))
print(len(leads.index)/9240)
# Out:
# 6373
# 0.6897186147186147

# %% [markdown]
# We still have around 69% of the rows which seems good enough.

# %%
# Let's look at the dataset again

leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email  Converted  TotalVisits  \
# 0      Olark Chat           No          0          0.0
# 1  Organic Search           No          0          5.0
# 2  Direct Traffic           No          1          2.0
# 3  Direct Traffic           No          0          1.0
# 4          Google           No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# 0                            0                   0.0  Page Visited on Website
# ...

# %%
# Dropping the columns 'Prospect ID' and 'Lead Number'
leads=leads.drop('Lead Number',axis=1)
leads=leads.drop('Prospect ID',axis=1)

# %% [markdown]
# # Step3:Prepare the data for modelling

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.pairplot(leads,diag_kind='kde',hue='Converted')
plt.show()

# %% [markdown]
# ###  Creating dummy variables

# %%
# Create dummy variables using the 'get_dummies' command
dummy = pd.get_dummies(leads[['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
                              'What is your current occupation','A free copy of Mastering The Interview', 
                              'Last Notable Activity']], drop_first=True)

# Add the results to the master dataframe
leads = pd.concat([leads, dummy], axis=1)

# %%
# Creating dummy variable separately for the variable 'Specialization' since it has the level 'Select' 
# which is useless so we drop that level by specifying it explicitly

dummy_spl = pd.get_dummies(leads['Specialization'], prefix = 'Specialization')
dummy_spl = dummy_spl.drop(['Specialization_Select'], 1)
leads = pd.concat([leads, dummy_spl], axis = 1)

# %%
# Drop the variables for which the dummy variables have been created

leads = leads.drop(['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
                   'Specialization', 'What is your current occupation',
                   'A free copy of Mastering The Interview', 'Last Notable Activity'], 1)

# %%
# lets look the data set again
leads.head()
# Out:
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
# 2                                    1                          0
# 3                                    1                          0
# 4                                    1                          0
#
#    Lead Origin_Lead Import  Lead Source_Direct Traffic  Lead Source_Facebook  \
# ...

# %% [markdown]
# ## Step 4: Exploratory data analysis

# %% [markdown]
# ### Univariate analysis

# %%
leads.Converted.value_counts(normalize=True)
# Out:
# 0    0.519065
# 1    0.480935
# Name: Converted, dtype: float64

# %%
leads.Converted.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# ### It shows data imbalance with ratio 51.9:48.09

# %% [markdown]
# ### TotalVisits variable

# %%
leads["TotalVisits"].value_counts(normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# #### numerical -numerical

# %% [markdown]
# ##### Converted vs TotalVisits

# %%
plt.scatter(leads.Converted,leads.TotalVisits)
plt.show()

# %% [markdown]
# ### They are not correlated with each other

# %%
leads["Converted_flag"]=np.where(leads.Converted==1,"yes","no")

# %%
leads["Converted_flag"].head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3     no
# 4    yes
# Name: Converted_flag, dtype: object

# %% [markdown]
# ### Numerical - Categorical

# %%
sns.boxplot(data=leads,x="Converted_flag",y="Total Time Spent on Website")
plt.show()

# %%
sns.boxplot(data=leads,x="Converted_flag",y="Page Views Per Visit")
plt.show()

# %%
leads.head()
# Out:
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
# 2                                    1                          0
# 3                                    1                          0
# 4                                    1                          0
#
#    Lead Origin_Lead Import  Lead Source_Direct Traffic  Lead Source_Facebook  \
# ...

# %%
num_var=['TotalVisits','Total Time Spent on Website','Page Views Per Visit']

# %%
sns.pairplot(leads[num_var])
plt.show()

# %% [markdown]
# ### Multivariate analysis

# %%
# Looking at the correlation table
plt.figure(figsize = (25,15))
sns.heatmap(leads.corr())
plt.show()

# %% [markdown]
# ## Step 5: Splitting the data

# %% [markdown]
# The next step is to split the dataset into training an testing sets.

# %% [markdown]
#  Test and Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting the data
X = leads.drop(['Converted','Converted_flag'], axis=1)

X.head()
# Out:
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
# 2                                    1                          0
# 3                                    1                          0
# 4                                    1                          0
#
#    Lead Origin_Lead Import  Lead Source_Direct Traffic  Lead Source_Facebook  \
# 0                        0                           0                     0
# ...

# %%
# Putting response variable to y
y = leads['Converted']

y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Converted, dtype: int64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=100)

# %% [markdown]
#  Scaling
#  Now there are a few numeric variables present in the dataset which have different scales. So let's go ahead and scale these variables.

# %%
# Import MinMax scaler

from sklearn.preprocessing import MinMaxScaler

# %%
# Scale the three numeric features present in the dataset
scaler = MinMaxScaler()
# fittransf on Xtrain
X_train[num_var]=scaler.fit_transform(X_train[num_var])

# transf X_test
X_test[num_var]=scaler.transform(X_test[num_var])

# %%
X_train.head()
# Out:
#       TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 8003     0.015936                     0.029489                 0.125
# 218      0.015936                     0.082306                 0.250
# 4171     0.023904                     0.034331                 0.375
# 4037     0.000000                     0.000000                 0.000
# 3660     0.000000                     0.000000                 0.000
#
#       Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 8003                                    1                          0
# 218                                     1                          0
# 4171                                    1                          0
# 4037                                    0                          0
# 3660                                    0                          1
#
#       Lead Origin_Lead Import  Lead Source_Direct Traffic  \
# 8003                        0                           1
# ...

# %%
X_train.describe()
# Out:
#        TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# count  4461.000000                  4461.000000           4461.000000
# mean      0.014528                     0.234426              0.153604
# std       0.021712                     0.248618              0.127910
# min       0.000000                     0.000000              0.000000
# 25%       0.003984                     0.014525              0.062500
# 50%       0.011952                     0.125440              0.125000
# 75%       0.019920                     0.448504              0.229375
# max       1.000000                     1.000000              1.000000
#
#        Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# count                          4461.000000                4461.000000
# mean                              0.564672                   0.094149
# std                               0.495856                   0.292069
# ...

# %% [markdown]
# ## Step 6: Model buliding Using RFE

# %% [markdown]
# Let's now move to model building. As you can see that there are a lot of variables present in the dataset which we cannot deal with. So the best way to approach this is to select a small set of features from this pool of variables using RFE.

# %%
# Import 'LogisticRegression' and create a LogisticRegression object

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
# Import RFE and select 15 variables

from sklearn.feature_selection import RFE
rfe = RFE(logreg,n_features_to_select=15)             # running RFE with 15 variables as output
rfe = rfe.fit(X_train, y_train)

# %%
# Let's take a look at which features have been selected by RFE

list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('TotalVisits', True, 1),
#  ('Total Time Spent on Website', True, 1),
#  ('Page Views Per Visit', False, 23),
#  ('Lead Origin_Landing Page Submission', False, 8),
#  ('Lead Origin_Lead Add Form', True, 1),
#  ('Lead Origin_Lead Import', False, 52),
#  ('Lead Source_Direct Traffic', False, 24),
#  ('Lead Source_Facebook', False, 51),
#  ('Lead Source_Google', False, 36),
#  ('Lead Source_Live Chat', False, 44),
#  ('Lead Source_Olark Chat', True, 1),
#  ('Lead Source_Organic Search', False, 35),
#  ('Lead Source_Pay per Click Ads', False, 43),
#  ('Lead Source_Press_Release', False, 53),
#  ('Lead Source_Reference', True, 1),
#  ('Lead Source_Referral Sites', False, 37),
#  ('Lead Source_Social Media', False, 58),
#  ('Lead Source_WeLearn', False, 42),
#  ('Lead Source_Welingak Website', True, 1),
#  ('Lead Source_bing', False, 33),
#  ('Lead Source_testone', False, 38),
#  ('Do Not Email_Yes', True, 1),
#  ('Last Activity_Converted to Lead', False, 25),
# ...

# %%
# Put all the columns selected by RFE in the variable 'col'
col=X_train.columns[rfe.support_]

# %%
# Select only the columns selected by RFE
X_train=X_train[col]

# %%
# Import statsmodels

import statsmodels.api as sm

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary

X_train_sm = sm.add_constant(X_train)
logm = sm.GLM(y_train, X_train_sm, family = sm.families.Binomial())
res = logm.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4445
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2072.8
# Date:                Mon, 09 Jan 2023   Deviance:                       4145.5
# Time:                        14:00:57   Pearson chi2:                 4.84e+03
# No. Iterations:                    22   Pseudo R-squ. (CS):             0.3660
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# There are quite a few variable which have a p-value greater than 0.05. We will need to take care of them. But first, let's also look at the VIFs.

# %%
# Import 'variance_inflation_factor'

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF dataframe for all the variables present

vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                              Features    VIF
# 2                           Lead Origin_Lead Add Form  84.19
# 4                               Lead Source_Reference  65.18
# 5                        Lead Source_Welingak Website  20.03
# 11         What is your current occupation_Unemployed   3.65
# 7              Last Activity_Had a Phone Conversation   2.44
# 13     Last Notable Activity_Had a Phone Conversation   2.43
# 1                         Total Time Spent on Website   2.38
# 0                                         TotalVisits   1.62
# 8                              Last Activity_SMS Sent   1.59
# 12  What is your current occupation_Working Profes...   1.56
# 3                              Lead Source_Olark Chat   1.44
# 6                                    Do Not Email_Yes   1.09
# 10            What is your current occupation_Student   1.09
# 9           What is your current occupation_Housewife   1.01
# ...

# %% [markdown]
# Let's first drop the variable Lead Source_Reference since it has a high p-value as well as a high VIF.

# %%
# Dropping the variable 'Lead Source_Reference'
X_train.drop('Lead Source_Reference', axis = 1, inplace = True)

# %%
# Again fitting the model

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4446
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2073.2
# Date:                Mon, 09 Jan 2023   Deviance:                       4146.5
# Time:                        14:00:57   Pearson chi2:                 4.82e+03
# No. Iterations:                    22   Pseudo R-squ. (CS):             0.3658
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                              Features   VIF
# 10         What is your current occupation_Unemployed  3.65
# 6              Last Activity_Had a Phone Conversation  2.44
# 12     Last Notable Activity_Had a Phone Conversation  2.43
# 1                         Total Time Spent on Website  2.38
# 2                           Lead Origin_Lead Add Form  1.71
# 0                                         TotalVisits  1.62
# 7                              Last Activity_SMS Sent  1.59
# 11  What is your current occupation_Working Profes...  1.56
# 3                              Lead Source_Olark Chat  1.44
# 4                        Lead Source_Welingak Website  1.33
# 5                                    Do Not Email_Yes  1.09
# 9             What is your current occupation_Student  1.09
# 8           What is your current occupation_Housewife  1.01
# 13                  Last Notable Activity_Unreachable  1.01

# %% [raw]
#  Based on VIF it seems all variables with good VIF values
#  But in case of P-Values, variable 'Last Notable Activity_Had a Phone Conversation' has 0.999 p-value. So, we need to drop that variable

# %%
# Dropping the variable 'Last Notable Activity_Had a Phone Conversation'
X_train.drop('Last Notable Activity_Had a Phone Conversation', axis = 1, inplace = True)

# %%
# Again fit the model

# %%
logm2 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4447
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2076.1
# Date:                Mon, 09 Jan 2023   Deviance:                       4152.2
# Time:                        14:00:57   Pearson chi2:                 4.82e+03
# No. Iterations:                    21   Pseudo R-squ. (CS):             0.3650
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# Refit the model with the new set of features
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                              Features   VIF
# 10         What is your current occupation_Unemployed  3.65
# 1                         Total Time Spent on Website  2.38
# 2                           Lead Origin_Lead Add Form  1.71
# 0                                         TotalVisits  1.62
# 7                              Last Activity_SMS Sent  1.59
# 11  What is your current occupation_Working Profes...  1.56
# 3                              Lead Source_Olark Chat  1.44
# 4                        Lead Source_Welingak Website  1.33
# 5                                    Do Not Email_Yes  1.09
# 9             What is your current occupation_Student  1.09
# 6              Last Activity_Had a Phone Conversation  1.01
# 8           What is your current occupation_Housewife  1.01
# 12                  Last Notable Activity_Unreachable  1.01

# %%
# Drop the variable 'What is your current occupation_Housewife'
X_train.drop('What is your current occupation_Housewife', axis = 1, inplace = True)

# %%
# Refitting the model

# %%
logm3 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm3.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4448
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2078.3
# Date:                Mon, 09 Jan 2023   Deviance:                       4156.7
# Time:                        14:00:57   Pearson chi2:                 4.83e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.3644
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# vif
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                              Features   VIF
# 9          What is your current occupation_Unemployed  3.64
# 1                         Total Time Spent on Website  2.37
# 2                           Lead Origin_Lead Add Form  1.70
# 0                                         TotalVisits  1.62
# 7                              Last Activity_SMS Sent  1.59
# 10  What is your current occupation_Working Profes...  1.56
# 3                              Lead Source_Olark Chat  1.44
# 4                        Lead Source_Welingak Website  1.33
# 5                                    Do Not Email_Yes  1.09
# 8             What is your current occupation_Student  1.09
# 6              Last Activity_Had a Phone Conversation  1.01
# 11                  Last Notable Activity_Unreachable  1.01

# %%
# Drop the variable 'What is your current occupation_Working Professional'
X_train.drop('What is your current occupation_Working Professional', axis = 1, inplace = True)

# %%
# Refitting the model
logm4 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm4.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4461
# Model:                            GLM   Df Residuals:                     4449
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2079.1
# Date:                Mon, 09 Jan 2023   Deviance:                       4158.1
# Time:                        14:00:57   Pearson chi2:                 4.80e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.3642
# Covariance Type:            nonrobust
# ...
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# vif
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                       Features   VIF
# 9   What is your current occupation_Unemployed  2.82
# 1                  Total Time Spent on Website  2.00
# 0                                  TotalVisits  1.54
# 7                       Last Activity_SMS Sent  1.51
# 2                    Lead Origin_Lead Add Form  1.45
# 3                       Lead Source_Olark Chat  1.33
# 4                 Lead Source_Welingak Website  1.30
# 5                             Do Not Email_Yes  1.08
# 8      What is your current occupation_Student  1.06
# 6       Last Activity_Had a Phone Conversation  1.01
# 10           Last Notable Activity_Unreachable  1.01

# %% [markdown]
# Now, both the p-values and VIFs seem decent enough for all the variables. So let's go ahead and make predictions using this final set of features.

# %% [markdown]
# ## Step 7: Model Evaluation

# %%
# Use 'predict' to predict the probabilities on the train set
y_train_pred = res.predict(X_train_sm).values.reshape(-1)

# %%
y_train_pred[:10]
# Out:
# array([0.29913183, 0.14183438, 0.12760155, 0.29167908, 0.95626237,
#        0.19443676, 0.17775018, 0.95285672, 0.07566484, 0.98233985])

# %%
# Create a new dataframe containing the actual conversion flag and the probabilities predicted by the model

y_train_pred_final = pd.DataFrame(
    {'Converted': y_train.values, 'Conversion_Prob': y_train_pred})
y_train_pred_final.head()
# Out:
#    Converted  Conversion_Prob
# 0          0         0.299132
# 1          0         0.141834
# 2          1         0.127602
# 3          1         0.291679
# 4          1         0.956262

# %%
# Creating new column 'predicted' with 1 if Conversion_Prob > 0.5 else 0
y_train_pred_final['predicted'] = y_train_pred_final.Conversion_Prob.map(lambda x: 1 if x > 0.5 else 0)
y_train_pred_final.head()
# Out:
#    Converted  Conversion_Prob  predicted
# 0          0         0.299132          0
# 1          0         0.141834          0
# 2          1         0.127602          0
# 3          1         0.291679          0
# 4          1         0.956262          1

# %%
# Import metrics from sklearn for evaluation

from sklearn import metrics

# %%
# Let's look at the confusion matrix 

confusion = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.predicted )
confusion
# Out:
# array([[1932,  380],
#        [ 562, 1587]], dtype=int64)

# %%
# checking the overall accuracy.
print(metrics.accuracy_score(y_train_pred_final.Converted, y_train_pred_final.predicted))
# Out:
# 0.788836583725622

# %%
# Let's evaluate the other metrics as well

TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Calculate the sensitivity

sensitivity=TP/(TP+FN)
sensitivity
# Out:
# 0.7384830153559795

# %%
# Calculate the specificity

specificity=TN/(TN+FP)
specificity
# Out:
# 0.8356401384083045

# %%
# Precision and Recall

# %%
#Looking at the confusion matrix again
confusion = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.predicted )
confusion
# Out:
# array([[1932,  380],
#        [ 562, 1587]], dtype=int64)

# %%
#Precision
#TP / TP + FP

# %%
confusion[1,1]/(confusion[0,1]+confusion[1,1])
# Out:
# 0.8068124046771734

# %%
#Recall
#TP / TP + FN

# %%
confusion[1,1]/(confusion[1,0]+confusion[1,1])
# Out:
# 0.7384830153559795

# %%
# Precision and recall tradeoff

# %%
from sklearn.metrics import precision_recall_curve

# %%
y_train_pred_final.Converted, y_train_pred_final.predicted
# Out:
# (0       0
#  1       0
#  2       1
#  3       1
#  4       1
#         ..
#  4456    1
#  4457    0
#  4458    0
#  4459    0
#  4460    0
#  Name: Converted, Length: 4461, dtype: int64,
#  0       0
#  1       0
#  2       0
#  3       0
#  4       1
#         ..
#  4456    1
#  4457    1
#  4458    1
#  4459    0
#  4460    0
#  Name: predicted, Length: 4461, dtype: int64)

# %%
# ROC function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
draw_roc(y_train_pred_final.Converted, y_train_pred_final.Conversion_Prob)

# %% [markdown]
# The area under the curve of the ROC is 0.86 which is quite good. So we seem to have a good model. Let's also check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %%
p, r, thresholds = precision_recall_curve(y_train_pred_final.Converted, y_train_pred_final.Conversion_Prob)

# %%
plt.plot(thresholds, p[:-1], "g-")
plt.plot(thresholds, r[:-1], "r-")
plt.show()

# %%
y_train_pred_final['final_predicted'] = y_train_pred_final.Conversion_Prob.map( lambda x: 1 if x > 0.3 else 0)

y_train_pred_final.head()
# Out:
#    Converted  Conversion_Prob  predicted  final_predicted
# 0          0         0.299132          0                0
# 1          0         0.141834          0                0
# 2          1         0.127602          0                0
# 3          1         0.291679          0                0
# 4          1         0.956262          1                1

# %%
metrics.accuracy_score(y_train_pred_final.Converted, y_train_pred_final.final_predicted)
# Out:
# 0.7673167451244116

# %%
confusion2 = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.final_predicted)
confusion2
# Out:
# array([[1564,  748],
#        [ 290, 1859]], dtype=int64)

# %%
# Let's evaluate the other metrics as well

TP = confusion2[1,1] # true positive 
TN = confusion2[0,0] # true negatives
FP = confusion2[0,1] # false positives
FN = confusion2[1,0] # false negatives

# %%
# Calculate Precision

TP/(TP+FP)
# Out:
# 0.7130801687763713

# %%
# Calculate Recall

TP/(TP+FN)
# Out:
# 0.8650535132619823

# %% [markdown]
# This cutoff point seems good to go!

# %% [markdown]
#  ## Step 8: Making Predictions on the Test Set

# %%
X_test[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']] = scaler.transform(X_test[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']])

# %%
X_test = X_test[col]
X_test.head()
# Out:
#       TotalVisits  Total Time Spent on Website  Lead Origin_Lead Add Form  \
# 4771     0.000000                     0.000000                          1
# 6122     0.000111                     0.000013                          0
# 9202     0.000063                     0.000183                          0
# 6570     0.000048                     0.000167                          0
# 2668     0.000127                     0.000174                          0
#
#       Lead Source_Olark Chat  Lead Source_Reference  \
# 4771                       0                      1
# 6122                       0                      0
# 9202                       0                      0
# 6570                       0                      0
# 2668                       0                      0
#
#       Lead Source_Welingak Website  Do Not Email_Yes  \
# 4771                             0                 0
# 6122                             0                 0
# ...

# %%
X_test_sm = sm.add_constant(X_test)

# %%
# Make predictions on the test set and store it in the variable 'y_test_pred'
y_test_pred = res.predict(X_test_sm)

# %%
y_test_pred[:10]
# Out:
# 4771    0.996661
# 6122    0.087519
# 9202    0.238421
# 6570    0.064954
# 2668    0.238544
# 4233    0.802832
# 3368    0.087552
# 9091    0.087607
# 5972    0.238219
# 3631    0.238485
# dtype: float64

# %%
# Converting y_pred to a dataframe which is an array
y_pred_1 = pd.DataFrame(y_test_pred)

# %%
# Let's see the head
y_pred_1.head()
# Out:
#              0
# 4771  0.996661
# 6122  0.087519
# 9202  0.238421
# 6570  0.064954
# 2668  0.238544

# %%
# Converting y_test to dataframe
y_test_df = pd.DataFrame(y_test)
y_test_df
# Out:
#       Converted
# 4771          1
# 6122          0
# 9202          0
# 6570          1
# 2668          1
# ...         ...
# 5828          0
# 6583          1
# 5531          0
# 3056          1
# 4088          1
#
# [1912 rows x 1 columns]

# %%
# Removing index for both dataframes to append them side by side 
y_pred_1.reset_index(drop=True, inplace=True)
y_test_df.reset_index(drop=True, inplace=True)

# %%
# Appending y_test_df and y_pred_1
y_pred_final = pd.concat([y_test_df, y_pred_1],axis=1)

# %%
# Check 'y_pred_final'

y_pred_final.head()
# Out:
#    Converted         0
# 0          1  0.996661
# 1          0  0.087519
# 2          0  0.238421
# 3          1  0.064954
# 4          1  0.238544

# %%
# Rename the column 
y_pred_final= y_pred_final.rename(columns = {0 : 'Conversion_Prob'})

# %%
y_pred_final.head()
# Out:
#    Converted  Conversion_Prob
# 0          1         0.996661
# 1          0         0.087519
# 2          0         0.238421
# 3          1         0.064954
# 4          1         0.238544

# %%
# Make predictions on the test set using 0.44 as the cutoff
y_pred_final['final_predicted'] = y_pred_final.Conversion_Prob.map(lambda x: 1 if x > 0.42 else 0)

# %%
y_pred_final.head()
# Out:
#    Converted  Conversion_Prob  final_predicted
# 0          1         0.996661                1
# 1          0         0.087519                0
# 2          0         0.238421                0
# 3          1         0.064954                0
# 4          1         0.238544                0

# %%
# checking the overall accuracy

metrics.accuracy_score(y_pred_final['Converted'], y_pred_final.final_predicted)
# Out:
# 0.6799163179916318

# %%
confusion2 = metrics.confusion_matrix(y_pred_final['Converted'], y_pred_final.final_predicted )
confusion2
# Out:
# array([[951,  45],
#        [567, 349]], dtype=int64)

# %%
TP = confusion2[1,1] # true positive 
TN = confusion2[0,0] # true negatives
FP = confusion2[0,1] # false positives
FN = confusion2[1,0] # false negatives

# %%
# Calculate Precision

Precision=TP/(TP+FP)
Precision
# Out:
# 0.8857868020304569

# %%
# Calculate Recall

Recall=TP/(TP+FN)
Recall
# Out:
# 0.38100436681222705
